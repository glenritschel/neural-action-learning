# %% [markdown]
# # Experiment 2: Search Performance Benchmarking
#
# Compare runtime, expanded nodes, and memory usage across DP, A* (with Euclidean/Manhattan), and Neural A*.

# %%
import os
import sys
# Add project root to python path
sys.path.append(os.path.abspath('..'))

import hydra
from hydra.core.global_hydra import GlobalHydra

import torch
import numpy as np
import pandas as pd

from environment.discrete_world import DiscreteWorld
from models.mlp import ActionMLP
from action.action_calculator import ActionCalculator
from visualization.plotting import plot_trajectory, plot_heatmap, plot_action_histogram, plot_latent_space

# Initialize Hydra configuration
GlobalHydra.instance().clear()
hydra.initialize(version_base=None, config_path="../config")
cfg = hydra.compose(config_name="config")

print(f"Loaded config: {cfg}")

# %% [markdown]
# ## Setup & Data Generation

# %%
# TODO: Implement data generation and setup specific to this experiment

# %% [markdown]
# ## Execution & Analysis

# %%
# TODO: Execute the main logic for this experiment

# %% [markdown]
# ## Visualization

# %%
# TODO: Use visualization utilities to plot the results
